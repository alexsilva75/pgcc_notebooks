# %%
import torchvision
from torchvision import models
import torch
from torch import nn
import torch.optim as optim
from torch.optim import lr_scheduler
from torchinfo import summary

# %% [markdown]
# ## VGG

# %%
vgg16 =  models.vgg16(weights=torchvision.models.VGG16_Weights.IMAGENET1K_V1, progress=True)
summary(vgg16)
# Out:
# ...
# Layer (type:depth-idx)                   Param #
# ...
# VGG                                      --
# ├─Sequential: 1-1                        --
# │    └─Conv2d: 2-1                       1,792
# │    └─ReLU: 2-2                         --
# │    └─Conv2d: 2-3                       36,928
# │    └─ReLU: 2-4                         --
# │    └─MaxPool2d: 2-5                    --
# │    └─Conv2d: 2-6                       73,856
# │    └─ReLU: 2-7                         --
# │    └─Conv2d: 2-8                       147,584
# │    └─ReLU: 2-9                         --
# │    └─MaxPool2d: 2-10                   --
# │    └─Conv2d: 2-11                      295,168
# │    └─ReLU: 2-12                        --
# │    └─Conv2d: 2-13                      590,080
# │    └─ReLU: 2-14                        --
# │    └─Conv2d: 2-15                      590,080
# │    └─ReLU: 2-16                        --
# │    └─MaxPool2d: 2-17                   --
# ...

# %%
for param in vgg16.parameters():
    print(param.requires_grad)
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True

# %% [markdown]
# ## ResNet 18

# %%
resnet18 = models.resnet18(weights=torchvision.models.ResNet18_Weights.IMAGENET1K_V1, progress=True)
summary(resnet18)
# Out:
# ...
# Layer (type:depth-idx)                   Param #
# ...
# ResNet                                   --
# ├─Conv2d: 1-1                            9,408
# ├─BatchNorm2d: 1-2                       128
# ├─ReLU: 1-3                              --
# ├─MaxPool2d: 1-4                         --
# ├─Sequential: 1-5                        --
# │    └─BasicBlock: 2-1                   --
# │    │    └─Conv2d: 3-1                  36,864
# │    │    └─BatchNorm2d: 3-2             128
# │    │    └─ReLU: 3-3                    --
# │    │    └─Conv2d: 3-4                  36,864
# │    │    └─BatchNorm2d: 3-5             128
# │    └─BasicBlock: 2-2                   --
# │    │    └─Conv2d: 3-6                  36,864
# │    │    └─BatchNorm2d: 3-7             128
# │    │    └─ReLU: 3-8                    --
# │    │    └─Conv2d: 3-9                  36,864
# │    │    └─BatchNorm2d: 3-10            128
# ├─Sequential: 1-6                        --
# │    └─BasicBlock: 2-3                   --
# ...

# %%
for param in resnet18.parameters():
    print(param.requires_grad)
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True

# %% [markdown]
# ## Inception V3

# %%
 inception3 = models.inception_v3(weights=torchvision.models.Inception_V3_Weights.IMAGENET1K_V1, progress=True)
summary(inception3)
# Out:
# ...
# Layer (type:depth-idx)                   Param #
# ...
# Inception3                               --
# ├─BasicConv2d: 1-1                       --
# │    └─Conv2d: 2-1                       864
# │    └─BatchNorm2d: 2-2                  64
# ├─BasicConv2d: 1-2                       --
# │    └─Conv2d: 2-3                       9,216
# │    └─BatchNorm2d: 2-4                  64
# ├─BasicConv2d: 1-3                       --
# │    └─Conv2d: 2-5                       18,432
# │    └─BatchNorm2d: 2-6                  128
# ├─MaxPool2d: 1-4                         --
# ├─BasicConv2d: 1-5                       --
# │    └─Conv2d: 2-7                       5,120
# │    └─BatchNorm2d: 2-8                  160
# ├─BasicConv2d: 1-6                       --
# │    └─Conv2d: 2-9                       138,240
# │    └─BatchNorm2d: 2-10                 384
# ├─MaxPool2d: 1-7                         --
# ├─InceptionA: 1-8                        --
# │    └─BasicConv2d: 2-11                 --
# ...

# %%
for param in inception3.parameters():
    print(param.requires_grad)
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# ...

# %% [markdown]
# ## EfficientNet B0

# %%
efficientnet_b0 =models.efficientnet_b0(weights=torchvision.models.EfficientNet_B0_Weights.IMAGENET1K_V1, progress=True)
summary(efficientnet_b0)
# Out:
# ...
# Layer (type:depth-idx)                                  Param #
# ...
# EfficientNet                                            --
# ├─Sequential: 1-1                                       --
# │    └─Conv2dNormActivation: 2-1                        --
# │    │    └─Conv2d: 3-1                                 864
# │    │    └─BatchNorm2d: 3-2                            64
# │    │    └─SiLU: 3-3                                   --
# │    └─Sequential: 2-2                                  --
# │    │    └─MBConv: 3-4                                 1,448
# │    └─Sequential: 2-3                                  --
# │    │    └─MBConv: 3-5                                 6,004
# │    │    └─MBConv: 3-6                                 10,710
# │    └─Sequential: 2-4                                  --
# │    │    └─MBConv: 3-7                                 15,350
# │    │    └─MBConv: 3-8                                 31,290
# │    └─Sequential: 2-5                                  --
# ...

# %%
for param in efficientnet_b0.parameters():
    print(param.requires_grad)
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# ...

# %% [markdown]
# # EfficientNet B4

# %%
efficientnet_b4 =models.efficientnet_b4(weights=torchvision.models.EfficientNet_B4_Weights.IMAGENET1K_V1, progress=True)
summary(efficientnet_b4)
# Out:
# Downloading: "https://download.pytorch.org/models/efficientnet_b4_rwightman-23ab8bcd.pth" to /home/alexsandro/.cache/torch/hub/checkpoints/efficientnet_b4_rwightman-23ab8bcd.pth
# 100%|██████████████████████████████████████| 74.5M/74.5M [01:11<00:00, 1.09MB/s]
# ...
# Layer (type:depth-idx)                                  Param #
# ...
# EfficientNet                                            --
# ├─Sequential: 1-1                                       --
# │    └─Conv2dNormActivation: 2-1                        --
# │    │    └─Conv2d: 3-1                                 1,296
# │    │    └─BatchNorm2d: 3-2                            96
# │    │    └─SiLU: 3-3                                   --
# │    └─Sequential: 2-2                                  --
# │    │    └─MBConv: 3-4                                 2,940
# │    │    └─MBConv: 3-5                                 1,206
# │    └─Sequential: 2-3                                  --
# ...

# %%
for param in efficientnet_b4.parameters():
    print(param.requires_grad)
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# ...

# %% [markdown]
# # ResNet 50

# %%
resnet50 = models.resnet50(weights=torchvision.models.ResNet50_Weights.IMAGENET1K_V1, progress=True)
summary(resnet50)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /home/alexsandro/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████████████████████████████████| 97.8M/97.8M [01:11<00:00, 1.44MB/s]
# ...
# Layer (type:depth-idx)                   Param #
# ...
# ResNet                                   --
# ├─Conv2d: 1-1                            9,408
# ├─BatchNorm2d: 1-2                       128
# ├─ReLU: 1-3                              --
# ├─MaxPool2d: 1-4                         --
# ├─Sequential: 1-5                        --
# │    └─Bottleneck: 2-1                   --
# │    │    └─Conv2d: 3-1                  4,096
# │    │    └─BatchNorm2d: 3-2             128
# │    │    └─Conv2d: 3-3                  36,864
# │    │    └─BatchNorm2d: 3-4             128
# │    │    └─Conv2d: 3-5                  16,384
# │    │    └─BatchNorm2d: 3-6             512
# │    │    └─ReLU: 3-7                    --
# │    │    └─Sequential: 3-8              16,896
# ...

# %%
for param in resnet50.parameters():
    print(param.requires_grad)
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# ...
