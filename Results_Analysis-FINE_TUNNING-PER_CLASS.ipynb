# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt 
import seaborn as sns 
from IPython.display import clear_output, display

# %% [markdown]
# # Results Fine Tunning

# %%
results_fine_tunning = pd.read_csv('./data/FINE_TUNNING_PER_CLASS_RESULTS_BASELINE_FIX_01.csv')
results_fine_tunning
# Out:
#             MODEL                           CLASS  FOLD DATASET COLOR_SPACE  \
# 0    efficientnet                        1_Normal     1     ROS         RGB
# 1    efficientnet                        1_Normal     2     ROS         RGB
# 2    efficientnet                        1_Normal     3     ROS         RGB
# 3    efficientnet                        1_Normal     4     ROS         RGB
# 4    efficientnet                        1_Normal     5     ROS         RGB
# ..            ...                             ...   ...     ...         ...
# 167     inception                        1_Normal     3     ROS         RGB
# 168     inception                        1_Normal     4     ROS         RGB
# 169     inception                        1_Normal     5     ROS         RGB
# 170     inception  2_Esclerose_Pura_Sem_Crescente     1     ROS         RGB
# 171     inception  2_Esclerose_Pura_Sem_Crescente     2     ROS         RGB
#
# ...

# %%
results_fine_tunning.MODEL.unique()
# Out:
# array(['efficientnet', 'efficientnet_b4', 'inception'], dtype=object)

# %%
results_fine_tunning.loc[results_fine_tunning['CLASS'] == '1_Normal'].sort_values(by=['MCC', 'F1', 'SENSITIVITY'], ascending=False).head(30)
# Out:
#                MODEL     CLASS  FOLD DATASET COLOR_SPACE  WEIGHTED_LOSS  \
# 161        inception  1_Normal     2     ROS         RGB          False
# 1       efficientnet  1_Normal     2     ROS         RGB          False
# 166        inception  1_Normal     2     ROS         RGB           True
# 3       efficientnet  1_Normal     4     ROS         RGB          False
# 4       efficientnet  1_Normal     5     ROS         RGB          False
# 168        inception  1_Normal     4     ROS         RGB           True
# 164        inception  1_Normal     5     ROS         RGB          False
# 169        inception  1_Normal     5     ROS         RGB           True
# 163        inception  1_Normal     4     ROS         RGB          False
# 7       efficientnet  1_Normal     3     ROS         RGB           True
# 6       efficientnet  1_Normal     2     ROS         RGB           True
# 8       efficientnet  1_Normal     4     ROS         RGB           True
# ...

# %%
results_fine_tunning[['MODEL','DATASET','FOLD', 'COLOR_SPACE','WEIGHTED_LOSS', 'MCC', 'F1','SENSITIVITY']].loc[results_fine_tunning['STAIN'] == 'PAMS'].sort_values(by=['MCC', 'F1', 'SENSITIVITY'], ascending=False)
# Out:
#                MODEL DATASET  FOLD COLOR_SPACE  WEIGHTED_LOSS       MCC  \
# 107        inception     ROS     3         RGB           True  0.948959
# 143         resnet18     ROS     4         RGB          False  0.924559
# 20      efficientnet     ROS     1         RGB          False  0.896236
# 148         resnet18     ROS     4         RGB           True  0.895409
# 145         resnet18     ROS     1         RGB           True  0.887798
# 147         resnet18     ROS     3         RGB           True  0.880129
# 225              vgg     ROS     1         RGB           True  0.878638
# 27      efficientnet     ROS     3         RGB           True  0.855963
# 224              vgg     ROS     5         RGB          False  0.839429
# 188         resnet50     ROS     4         RGB           True  0.833415
# 23      efficientnet     ROS     4         RGB          False  0.824815
# 223              vgg     ROS     4         RGB          False  0.823415
# ...

# %% [markdown]
# # Inception (PAMS)

# %%
from_scratch_Inception3 = results_fine_tunning[['MODEL','DATASET','FOLD', 'COLOR_SPACE','WEIGHTED_LOSS', 'MCC', 'F1','SENSITIVITY']].loc[(results_fine_tunning['STAIN'] == 'PAMS') & (results_fine_tunning['MODEL'] == 'inception') & (results_fine_tunning['WEIGHTED_LOSS'] == True)].sort_values(by=['MCC', 'F1', 'SENSITIVITY'], ascending=False)
from_scratch_Inception3
# Out:
#          MODEL DATASET  FOLD COLOR_SPACE  WEIGHTED_LOSS       MCC        F1  \
# 107  inception     ROS     3         RGB           True  0.948959  0.974648
# 108  inception     ROS     4         RGB           True  0.772934  0.863636
# 106  inception     ROS     2         RGB           True  0.735147  0.839744
# 105  inception     ROS     1         RGB           True  0.729917  0.830065
# 109  inception     ROS     5         RGB           True  0.630745  0.751773
#
#      SENSITIVITY
# 107     0.988571
# 108     0.773256
# 106     0.744318
# 105     0.721591
# 109     0.619883

# %%
from_scratch_Inception3.MCC.mean()
# Out:
# 0.7635403491301551

# %%
from_scratch_Inception3.MCC.std()
# Out:
# 0.1162320198408683

# %% [markdown]
# # ResNet18 (PAMS)

# %%
from_scratch_resnet18 = results_fine_tunning[['MODEL','DATASET','FOLD', 'COLOR_SPACE','WEIGHTED_LOSS', 'MCC', 'F1','SENSITIVITY']].loc[(results_fine_tunning['STAIN'] == 'PAMS') & (results_fine_tunning['MODEL'] == 'resnet18')  & (results_fine_tunning['WEIGHTED_LOSS'] == False)].sort_values(by=['MCC', 'F1', 'SENSITIVITY'], ascending=False)
from_scratch_resnet18
# Out:
#         MODEL DATASET  FOLD COLOR_SPACE  WEIGHTED_LOSS       MCC        F1  \
# 143  resnet18     ROS     4         RGB          False  0.924559  0.961877
# 142  resnet18     ROS     3         RGB          False  0.747563  0.844156
# 140  resnet18     ROS     1         RGB          False  0.710122  0.802721
# 141  resnet18     ROS     2         RGB          False  0.643160  0.738351
# 144  resnet18     ROS     5         RGB          False  0.552454  0.645669
#
#      SENSITIVITY
# 143     0.953488
# 142     0.742857
# 140     0.670455
# 141     0.585227
# 144     0.479532

# %% [markdown]
# # EfficientNetB0 (PAMS)

# %%
from_scratch_efficientnet_b0 = results_fine_tunning[['MODEL','DATASET','FOLD', 'COLOR_SPACE','WEIGHTED_LOSS', 'MCC', 'F1','SENSITIVITY']].loc[(results_fine_tunning['STAIN'] == 'PAMS') & (results_fine_tunning['MODEL'] == 'efficientnet')  & (results_fine_tunning['WEIGHTED_LOSS'] == False)].sort_values(by=['MCC', 'F1', 'SENSITIVITY'], ascending=False)
from_scratch_efficientnet_b0
# Out:
#            MODEL DATASET  FOLD COLOR_SPACE  WEIGHTED_LOSS       MCC        F1  \
# 20  efficientnet     ROS     1         RGB          False  0.896236  0.943284
# 23  efficientnet     ROS     4         RGB          False  0.824815  0.904615
# 22  efficientnet     ROS     3         RGB          False  0.821365  0.892405
# 24  efficientnet     ROS     5         RGB          False  0.818483  0.900621
# 21  efficientnet     ROS     2         RGB          False  0.792789  0.883436
#
#     SENSITIVITY
# 20     0.897727
# 23     0.854651
# 22     0.805714
# 24     0.847953
# 21     0.818182

# %%
from_scratch_efficientnet_b0.MCC.mean()
# Out:
# 0.8307378159052444

# %%
from_scratch_efficientnet_b0.MCC.std()
# Out:
# 0.03874021254156598

# %% [markdown]
# # PAS

# %%
results_fine_tunning[['MODEL','DATASET','FOLD', 'COLOR_SPACE','WEIGHTED_LOSS', 'MCC', 'F1','SENSITIVITY']].loc[results_fine_tunning['STAIN'] == 'PAS'].sort_values(by=['MCC', 'F1', 'SENSITIVITY'], ascending=False)
# Out:
#                MODEL DATASET  FOLD COLOR_SPACE  WEIGHTED_LOSS       MCC  \
# 36      efficientnet     ROS     2         RGB           True  0.976513
# 156         resnet18     ROS     2         RGB           True  0.928718
# 196         resnet50     ROS     2         RGB           True  0.921146
# 238              vgg     ROS     4         RGB           True  0.918444
# 31      efficientnet     ROS     2         RGB          False  0.915748
# 197         resnet50     ROS     3         RGB           True  0.911506
# 158         resnet18     ROS     4         RGB           True  0.891729
# 233              vgg     ROS     4         RGB          False  0.885240
# 236              vgg     ROS     2         RGB           True  0.871067
# 35      efficientnet     ROS     1         RGB           True  0.867629
# 191         resnet50     ROS     2         RGB          False  0.867542
# 33      efficientnet     ROS     4         RGB          False  0.859168
# ...

# %% [markdown]
# # EfficientNetB0 (PAS)

# %%
efficientnet_b0 = results_fine_tunning[['MODEL','DATASET','FOLD', 'COLOR_SPACE','WEIGHTED_LOSS', 'MCC', 'F1','SENSITIVITY']].loc[(results_fine_tunning['STAIN'] == 'PAS') & (results_fine_tunning['MODEL'] == 'efficientnet')  & (results_fine_tunning['WEIGHTED_LOSS'] == True)].sort_values(by=['MCC', 'F1', 'SENSITIVITY'], ascending=False)
efficientnet_b0
# Out:
#            MODEL DATASET  FOLD COLOR_SPACE  WEIGHTED_LOSS       MCC        F1  \
# 36  efficientnet     ROS     2         RGB           True  0.976513  0.988258
# 35  efficientnet     ROS     1         RGB           True  0.867629  0.926778
# 38  efficientnet     ROS     4         RGB           True  0.833196  0.911917
# 39  efficientnet     ROS     5         RGB           True  0.813481  0.898520
# 37  efficientnet     ROS     3         RGB           True  0.749547  0.854326
#
#     SENSITIVITY
# 36     1.000000
# 35     0.873767
# 38     0.876494
# 39     0.848303
# 37     0.773810

# %%
efficientnet_b0.MCC.mean()
# Out:
# 0.8480731623343635

# %%
efficientnet_b0.MCC.std()
# Out:
# 0.08367300582023146

# %% [markdown]
# # ResNet18 (PAS)

# %%
resnet18 = results_fine_tunning[['MODEL','DATASET','FOLD', 'COLOR_SPACE','WEIGHTED_LOSS', 'MCC', 'F1','SENSITIVITY']].loc[(results_fine_tunning['STAIN'] == 'PAS') & (results_fine_tunning['MODEL'] == 'resnet18')  & (results_fine_tunning['WEIGHTED_LOSS'] == True)].sort_values(by=['MCC', 'F1', 'SENSITIVITY'], ascending=False)
resnet18
# Out:
#         MODEL DATASET  FOLD COLOR_SPACE  WEIGHTED_LOSS       MCC        F1  \
# 156  resnet18     ROS     2         RGB           True  0.928718  0.962129
# 158  resnet18     ROS     4         RGB           True  0.891729  0.943705
# 155  resnet18     ROS     1         RGB           True  0.800485  0.877076
# 157  resnet18     ROS     3         RGB           True  0.746787  0.842938
# 159  resnet18     ROS     5         RGB           True  0.644988  0.751232
#
#      SENSITIVITY
# 156     0.930693
# 158     0.918327
# 155     0.781065
# 157     0.740079
# 159     0.608782

# %%
resnet18.MCC.mean()
# Out:
# 0.8025414421269019

# %%
resnet18.MCC.std()
# Out:
# 0.11380971509182893

# %% [markdown]
# # ResNet50 (PAS)

# %%
resnet50 = results_fine_tunning[['MODEL','DATASET','FOLD', 'COLOR_SPACE','WEIGHTED_LOSS', 'MCC', 'F1','SENSITIVITY']].loc[(results_fine_tunning['STAIN'] == 'PAS') & (results_fine_tunning['MODEL'] == 'resnet50')  & (results_fine_tunning['WEIGHTED_LOSS'] == True)].sort_values(by=['MCC', 'F1', 'SENSITIVITY'], ascending=False)
resnet50
# Out:
#         MODEL DATASET  FOLD COLOR_SPACE  WEIGHTED_LOSS       MCC        F1  \
# 196  resnet50     ROS     2         RGB           True  0.921146  0.959839
# 197  resnet50     ROS     3         RGB           True  0.911506  0.954407
# 195  resnet50     ROS     1         RGB           True  0.828925  0.901499
# 198  resnet50     ROS     4         RGB           True  0.784320  0.882540
# 199  resnet50     ROS     5         RGB           True  0.694293  0.799528
#
#      SENSITIVITY
# 196     0.946535
# 197     0.934524
# 195     0.830375
# 198     0.830677
# 199     0.676647

# %%
resnet50.MCC.mean()
# Out:
# 0.8280379536172067

# %%
resnet50.MCC.std()
# Out:
# 0.09412203731824155
