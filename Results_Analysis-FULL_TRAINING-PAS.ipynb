# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt 
import seaborn as sns 
from IPython.display import clear_output, display

# %% [markdown]
# # Results Full Training on Test Set

# %%
results_full_training = pd.read_csv('./data/FULL_TRAINING_PER_STAIN_PAMS.csv')
results_full_training
# Out:
#           MODEL  FOLD DATASET COLOR_SPACE  WEIGHTED_LOSS  TRUE_NEGATIVES  \
# 0    Inception3     0     ROS         RGB          False             287
# 1    Inception3     0     ROS         RGB           True             287
# 2        ResNet     0     ROS         RGB          False             286
# 3        ResNet     0     ROS         RGB           True             286
# 4  EfficientNet     0     ROS         RGB          False             288
# 5  EfficientNet     0     ROS         RGB           True             284
#
#    FALSE_POSITIVES  FALSE_NEGATIVES  TRUE_POSITIVES      LOSS       ACC  \
# 0                1                9              15  0.079776  0.967949
# 1                1                7              17  0.070210  0.974359
# 2                2                7              17  0.115854  0.971154
# 3                2                5              19  0.110565  0.977564
# 4                0                5              19  0.059732  0.983974
# 5                4                2              22  0.074919  0.980769
#
#    SENSITIVITY  SPECIFITY  PRECISION        F1       AUC       MCC
# 0     0.625000   0.996528   0.937500  0.750000  0.810764  0.750856
# 1     0.708333   0.996528   0.944444  0.809524  0.852431  0.805556
# 2     0.708333   0.993056   0.894737  0.790698  0.850694  0.781538
# 3     0.791667   0.993056   0.904762  0.844444  0.892361  0.834568
# 4     0.791667   1.000000   1.000000  0.883721  0.895833  0.882132
# 5     0.916667   0.986111   0.846154  0.880000  0.951389  0.870388

# %%
results_full_training.sort_values(by=['MCC', 'F1', 'SENSITIVITY'], ascending=False)
# Out:
#           MODEL  FOLD DATASET COLOR_SPACE  WEIGHTED_LOSS  TRUE_NEGATIVES  \
# 4  EfficientNet     0     ROS         RGB          False             288
# 5  EfficientNet     0     ROS         RGB           True             284
# 3        ResNet     0     ROS         RGB           True             286
# 1    Inception3     0     ROS         RGB           True             287
# 2        ResNet     0     ROS         RGB          False             286
# 0    Inception3     0     ROS         RGB          False             287
#
#    FALSE_POSITIVES  FALSE_NEGATIVES  TRUE_POSITIVES      LOSS       ACC  \
# 4                0                5              19  0.059732  0.983974
# 5                4                2              22  0.074919  0.980769
# 3                2                5              19  0.110565  0.977564
# 1                1                7              17  0.070210  0.974359
# 2                2                7              17  0.115854  0.971154
# 0                1                9              15  0.079776  0.967949
#
#    SENSITIVITY  SPECIFITY  PRECISION        F1       AUC       MCC
# 4     0.791667   1.000000   1.000000  0.883721  0.895833  0.882132
# 5     0.916667   0.986111   0.846154  0.880000  0.951389  0.870388
# 3     0.791667   0.993056   0.904762  0.844444  0.892361  0.834568
# 1     0.708333   0.996528   0.944444  0.809524  0.852431  0.805556
# 2     0.708333   0.993056   0.894737  0.790698  0.850694  0.781538
# 0     0.625000   0.996528   0.937500  0.750000  0.810764  0.750856
