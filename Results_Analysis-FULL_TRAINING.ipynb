# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt 
import seaborn as sns 
from IPython.display import clear_output, display

# %% [markdown]
# # Results Full Training on Test Set

# %%
results_full_training = pd.read_csv('./data/FULL_TRAINING_EFFICIENTNET_B0-RESNET50-VGG_ALL_DATA_RESULTS_BASELINE.csv')
results_full_training
# Out:
#           MODEL  FOLD DATASET COLOR_SPACE  WEIGHTED_LOSS  TRUE_NEGATIVES  \
# 0  EfficientNet     0     ROS         RGB          False            2814
# 1  EfficientNet     0     ROS         RGB           True            2806
# 2        ResNet     0     ROS         RGB          False            2812
# 3        ResNet     0     ROS         RGB           True            2808
# 4           VGG     0     ROS         RGB          False            2810
# 5           VGG     0     ROS         RGB           True            2805
#
#    FALSE_POSITIVES  FALSE_NEGATIVES  TRUE_POSITIVES      LOSS       ACC  \
# 0                2               28              64  0.039172  0.989684
# 1               10               17              75  0.026292  0.990715
# 2                4               28              64  0.049197  0.988996
# 3                8               18              74  0.026807  0.991059
# 4                6               24              68  0.077069  0.989684
# 5               11                9              83  0.040931  0.993122
#
#    SENSITIVITY  SPECIFITY  PRECISION        F1       AUC       MCC
# 0     0.695652   0.999290   0.969697  0.810127  0.847471  0.816723
# 1     0.815217   0.996449   0.882353  0.847458  0.905833  0.843379
# 2     0.695652   0.998580   0.941176  0.800000  0.847116  0.804083
# 3     0.804348   0.997159   0.902439  0.850575  0.900753  0.847470
# 4     0.739130   0.997869   0.918919  0.819277  0.868500  0.819147
# 5     0.902174   0.996094   0.882979  0.892473  0.949134  0.888976

# %%
results_full_training.sort_values(by=['MCC', 'F1', 'SENSITIVITY'], ascending=False)
# Out:
#           MODEL  FOLD DATASET COLOR_SPACE  WEIGHTED_LOSS  TRUE_NEGATIVES  \
# 5           VGG     0     ROS         RGB           True            2805
# 3        ResNet     0     ROS         RGB           True            2808
# 1  EfficientNet     0     ROS         RGB           True            2806
# 4           VGG     0     ROS         RGB          False            2810
# 0  EfficientNet     0     ROS         RGB          False            2814
# 2        ResNet     0     ROS         RGB          False            2812
#
#    FALSE_POSITIVES  FALSE_NEGATIVES  TRUE_POSITIVES      LOSS       ACC  \
# 5               11                9              83  0.040931  0.993122
# 3                8               18              74  0.026807  0.991059
# 1               10               17              75  0.026292  0.990715
# 4                6               24              68  0.077069  0.989684
# 0                2               28              64  0.039172  0.989684
# 2                4               28              64  0.049197  0.988996
#
#    SENSITIVITY  SPECIFITY  PRECISION        F1       AUC       MCC
# 5     0.902174   0.996094   0.882979  0.892473  0.949134  0.888976
# 3     0.804348   0.997159   0.902439  0.850575  0.900753  0.847470
# 1     0.815217   0.996449   0.882353  0.847458  0.905833  0.843379
# 4     0.739130   0.997869   0.918919  0.819277  0.868500  0.819147
# 0     0.695652   0.999290   0.969697  0.810127  0.847471  0.816723
# 2     0.695652   0.998580   0.941176  0.800000  0.847116  0.804083
