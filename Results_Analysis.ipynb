# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt 
import seaborn as sns 
from IPython.display import clear_output, display

# %% [markdown]
# # Results From Scratch

# %%
results_from_scratch = pd.read_csv('./data/FROM_SCRATCH_VAL_RESULTS_BASELINE.csv')
results_from_scratch
# Out:
#            MODEL  FOLD DATASET COLOR_SPACE  WEIGHTED_LOSS  TRUE_NEGATIVES  \
# 0   EfficientNet     1     ROS         RGB          False            1691
# 1   EfficientNet     2     ROS         RGB          False            1672
# 2   EfficientNet     3     ROS         RGB          False            1654
# 3   EfficientNet     4     ROS         RGB          False            1670
# 4   EfficientNet     5     ROS         RGB          False            1656
# ..           ...   ...     ...         ...            ...             ...
# 58           VGG     1     ROS         RGB           True            1410
# 59           VGG     2     ROS         RGB           True            1417
# 60           VGG     3     ROS         RGB           True            1394
# 61           VGG     4     ROS         RGB           True            1384
# 62           VGG     5     ROS         RGB           True            1463
#
#     FALSE_POSITIVES  FALSE_NEGATIVES  TRUE_POSITIVES      LOSS       ACC  \
# ...

# %%
results_from_scratch.MODEL.unique()
# Out:
# array(['EfficientNet', 'Inception3', 'ResNet', 'VGG'], dtype=object)

# %%
results_from_scratch[['MODEL','DATASET','FOLD', 'COLOR_SPACE','WEIGHTED_LOSS', 'MCC', 'F1','SENSITIVITY']].sort_values(by=['MCC', 'F1', 'SENSITIVITY'], ascending=False)
# Out:
#            MODEL DATASET  FOLD COLOR_SPACE  WEIGHTED_LOSS       MCC        F1  \
# 20    Inception3     ROS     1         RGB          False  0.846216  0.919394
# 48        ResNet     ROS     1         RGB           True  0.817433  0.910936
# 24    Inception3     ROS     5         RGB          False  0.800700  0.896573
# 13  EfficientNet     ROS     4         RGB          False  0.791763  0.882635
# 39        ResNet     ROS     5         RGB           True  0.788553  0.880309
# ..           ...     ...   ...         ...            ...       ...       ...
# 2   EfficientNet     ROS     3         RGB          False  0.494888  0.607029
# 33        ResNet     ROS     4         RGB          False  0.471038  0.552163
# 34        ResNet     ROS     5         RGB          False  0.458286  0.533448
# 30        ResNet     ROS     1         RGB          False  0.451071  0.516631
# 32        ResNet     ROS     3         RGB          False  0.356387  0.375000
#
#     SENSITIVITY
# ...

# %%
from_scratch_Inception3 = results_from_scratch[['MODEL','DATASET','FOLD', 'COLOR_SPACE','WEIGHTED_LOSS', 'MCC', 'F1','SENSITIVITY']].loc[results_from_scratch['MODEL'] == 'Inception3'].sort_values(by=['MCC', 'F1', 'SENSITIVITY'], ascending=False)
from_scratch_Inception3
# Out:
#          MODEL DATASET  FOLD COLOR_SPACE  WEIGHTED_LOSS       MCC        F1  \
# 20  Inception3     ROS     1         RGB          False  0.846216  0.919394
# 24  Inception3     ROS     5         RGB          False  0.800700  0.896573
# 21  Inception3     ROS     2         RGB          False  0.787600  0.887250
# 29  Inception3     ROS     5         RGB           True  0.758037  0.882166
# 25  Inception3     ROS     1         RGB           True  0.742053  0.875131
# 28  Inception3     ROS     4         RGB           True  0.711716  0.862234
# 23  Inception3     ROS     4         RGB          False  0.708308  0.826578
# 22  Inception3     ROS     3         RGB          False  0.684193  0.824018
# 27  Inception3     ROS     3         RGB           True  0.647298  0.831672
# 26  Inception3     ROS     2         RGB           True  0.646688  0.832883
#
#     SENSITIVITY
# 20     0.888173
# 24     0.869952
# 21     0.847915
# 29     0.986936
# 25     0.980679
# 28     0.959172
# ...

# %% [markdown]
# # Results for Fine Tunning

# %%
results_fine_tunning = pd.read_csv('./data/FINE_TUNNING_VAL_RESULTS_BASELINE.csv')
results_fine_tunning.head()
# Out:
#           MODEL  FOLD DATASET COLOR_SPACE  WEIGHTED_LOSS  TRUE_NEGATIVES  \
# 0      resnet50     1     ROS         RGB          False            1706
# 1      resnet50     2     ROS         RGB          False            1695
# 2  efficientnet     1     ROS         RGB          False            1707
# 3      resnet50     3     ROS         RGB          False            1690
# 4  efficientnet     2     ROS         RGB          False            1697
#
#    FALSE_POSITIVES  FALSE_NEGATIVES  TRUE_POSITIVES      LOSS       ACC  \
# 0                2              374            1334  0.319305  0.889930
# 1                8              254            1449  0.245436  0.923077
# 2                1              411            1297  0.508631  0.879391
# 3                9              325            1374  0.407954  0.901707
# 4                6              256            1447  0.269736  0.923077
#
#    SENSITIVITY  SPECIFITY  PRECISION        F1       AUC       MCC
# ...

# %%
results_fine_tunning[['MODEL','DATASET','FOLD', 'COLOR_SPACE','WEIGHTED_LOSS', 'MCC', 'F1','SENSITIVITY']].sort_values(by=['MCC', 'F1', 'SENSITIVITY'], ascending=False)
# Out:
#               MODEL DATASET  FOLD COLOR_SPACE  WEIGHTED_LOSS       MCC  \
# 15     efficientnet     ROS     4         RGB           True  0.953268
# 7      efficientnet     ROS     4         RGB          False  0.926575
# 14         resnet50     ROS     2         RGB           True  0.912320
# 12     efficientnet     ROS     2         RGB           True  0.907054
# 21  efficientnet_b4     ROS     2         RGB          False  0.881970
# 10     efficientnet     ROS     1         RGB           True  0.881021
# 48         resnet18     ROS     4         RGB           True  0.862458
# 23  efficientnet_b4     ROS     4         RGB          False  0.859187
# 46         resnet18     ROS     2         RGB           True  0.855583
# 4      efficientnet     ROS     2         RGB          False  0.855421
# 1          resnet50     ROS     2         RGB          False  0.855122
# 11         resnet50     ROS     1         RGB           True  0.847471
# ...

# %% [markdown]
# ## Results for EfficientNet Fine Tunning

# %%
results_efficientnet = results_fine_tunning[['MODEL','DATASET','FOLD', 'COLOR_SPACE','WEIGHTED_LOSS', 'MCC', 'F1','SENSITIVITY']].loc[(results_fine_tunning['MODEL'] == 'efficientnet') & (results_fine_tunning['WEIGHTED_LOSS'] == True)].sort_values(by=['MCC', 'F1', 'SENSITIVITY'], ascending=False)
results_efficientnet
# Out:
#            MODEL DATASET  FOLD COLOR_SPACE  WEIGHTED_LOSS       MCC        F1  \
# 15  efficientnet     ROS     4         RGB           True  0.953268  0.976689
# 12  efficientnet     ROS     2         RGB           True  0.907054  0.950730
# 10  efficientnet     ROS     1         RGB           True  0.881021  0.935464
# 17  efficientnet     ROS     5         RGB           True  0.841086  0.910424
# 13  efficientnet     ROS     3         RGB           True  0.806160  0.886665
#
#     SENSITIVITY
# 15     0.979290
# 12     0.917792
# 10     0.891101
# 17     0.847981
# 13     0.808122

# %%
results_efficientnet.MCC.mean()
# Out:
# 0.8777177977887772

# %%
results_efficientnet.MCC.std()
# Out:
# 0.05710016863519094

# %% [markdown]
# ## Results for ResNet 50 Fine Tunning

# %%
results_resnet50 = results_fine_tunning[['MODEL','DATASET','FOLD', 'COLOR_SPACE','WEIGHTED_LOSS', 'MCC', 'F1','SENSITIVITY']].loc[(results_fine_tunning['MODEL'] == 'resnet50') & (results_fine_tunning['WEIGHTED_LOSS'] == True)].sort_values(by=['MCC', 'F1', 'SENSITIVITY'], ascending=False)
results_resnet50
# Out:
#        MODEL DATASET  FOLD COLOR_SPACE  WEIGHTED_LOSS       MCC        F1  \
# 14  resnet50     ROS     2         RGB           True  0.912320  0.954023
# 11  resnet50     ROS     1         RGB           True  0.847471  0.912314
# 18  resnet50     ROS     4         RGB           True  0.805381  0.885342
# 16  resnet50     ROS     3         RGB           True  0.792308  0.872895
# 20  resnet50     ROS     5         RGB           True  0.792272  0.876153
#
#     SENSITIVITY
# 14     0.926013
# 11     0.843677
# 18     0.804142
# 16     0.778105
# 20     0.789786

# %%
results_resnet50.MCC.mean()
# Out:
# 0.829950408734583

# %%
results_resnet50.MCC.std()
# Out:
# 0.05131262670238323

# %% [markdown]
# ## Results for EfficientNet B4 Fine Tunning

# %%
results_efficientnet_b4 = results_fine_tunning[['MODEL','DATASET','FOLD', 'COLOR_SPACE','WEIGHTED_LOSS', 'MCC', 'F1','SENSITIVITY']].loc[(results_fine_tunning['MODEL'] == 'efficientnet_b4')].sort_values(by=['MCC', 'F1', 'SENSITIVITY'], ascending=False)
results_efficientnet_b4
# Out:
#               MODEL DATASET  FOLD COLOR_SPACE  WEIGHTED_LOSS       MCC  \
# 21  efficientnet_b4     ROS     2         RGB          False  0.881970
# 23  efficientnet_b4     ROS     4         RGB          False  0.859187
# 19  efficientnet_b4     ROS     1         RGB          False  0.809286
# 24  efficientnet_b4     ROS     5         RGB          False  0.807886
# 22  efficientnet_b4     ROS     3         RGB          False  0.759527
# 25  efficientnet_b4     ROS     1         RGB           True  0.694545
# 29  efficientnet_b4     ROS     5         RGB           True  0.691261
# 27  efficientnet_b4     ROS     3         RGB           True  0.677526
# 26  efficientnet_b4     ROS     2         RGB           True  0.670471
# 28  efficientnet_b4     ROS     4         RGB           True  0.638551
#
#           F1  SENSITIVITY
# 21  0.939593     0.922490
# 23  0.929377     0.926627
# 19  0.899452     0.864169
# 24  0.897731     0.857482
# 22  0.864796     0.798117
# ...

# %%
results_efficientnet_b4.MCC.mean()
# Out:
# 0.8235711908304498

# %%
results_efficientnet_b4.MCC.std()
# Out:
# 0.04803833869141595

# %% [markdown]
# ## Results for ResNet 18 Fine Tunning

# %%
results_resnet18 = results_fine_tunning[['MODEL','DATASET','FOLD', 'COLOR_SPACE','WEIGHTED_LOSS', 'MCC', 'F1','SENSITIVITY']].loc[(results_fine_tunning['MODEL'] == 'resnet18')].sort_values(by=['MCC', 'F1', 'SENSITIVITY'], ascending=False)
results_resnet18
# Out:
#        MODEL DATASET  FOLD COLOR_SPACE  WEIGHTED_LOSS       MCC        F1  \
# 48  resnet18     ROS     4         RGB           True  0.862458  0.923513
# 46  resnet18     ROS     2         RGB           True  0.855583  0.917981
# 45  resnet18     ROS     1         RGB           True  0.828873  0.899294
# 43  resnet18     ROS     4         RGB          False  0.808151  0.884805
# 41  resnet18     ROS     2         RGB          False  0.807917  0.883066
# 49  resnet18     ROS     5         RGB           True  0.783718  0.867446
# 47  resnet18     ROS     3         RGB           True  0.752097  0.842141
# 40  resnet18     ROS     1         RGB          False  0.716131  0.808095
# 44  resnet18     ROS     5         RGB          False  0.715526  0.809171
# 42  resnet18     ROS     3         RGB          False  0.701020  0.796610
#
#     SENSITIVITY
# 48     0.868047
# 46     0.854375
# 45     0.820843
# 43     0.797633
# 41     0.791544
# 49     0.771378
# 47     0.731607
# ...

# %%
results_resnet18.MCC.mean()
# Out:
# 0.8165458077809665

# %%
results_resnet18.MCC.std()
# Out:
# 0.047473816884828796

# %% [markdown]
# ## Results for Inception Fine Tunning

# %%
results_inception = results_fine_tunning[['MODEL','DATASET','FOLD', 'COLOR_SPACE','WEIGHTED_LOSS', 'MCC', 'F1','SENSITIVITY']].loc[(results_fine_tunning['MODEL'] == 'inception')].sort_values(by=['MCC', 'F1', 'SENSITIVITY'], ascending=False)
results_inception
# Out:
#         MODEL DATASET  FOLD COLOR_SPACE  WEIGHTED_LOSS       MCC        F1  \
# 30  inception     ROS     1         RGB          False  0.844648  0.909091
# 33  inception     ROS     4         RGB          False  0.817657  0.891212
# 35  inception     ROS     1         RGB           True  0.808032  0.883600
# 31  inception     ROS     2         RGB          False  0.800194  0.877100
# 39  inception     ROS     5         RGB           True  0.796677  0.874958
# 38  inception     ROS     4         RGB           True  0.794278  0.874379
# 34  inception     ROS     5         RGB          False  0.781007  0.862732
# 36  inception     ROS     2         RGB           True  0.773767  0.857907
# 32  inception     ROS     3         RGB          False  0.727580  0.819285
# 37  inception     ROS     3         RGB           True  0.713738  0.807975
#
#     SENSITIVITY
# 30     0.834309
# 33     0.807101
# 35     0.793326
# 31     0.781562
# 39     0.779097
# 38     0.780473
# 34     0.759501
# ...

# %% [markdown]
# ## Results for VGG Fine Tunning

# %%
results_vgg = pd.read_csv('./data/VGG_FINE_TUNNING_VAL_RESULTS_BASELINE.csv')
results_vgg.sort_values(by=['MCC', 'F1', 'SENSITIVITY'], ascending=False)
# Out:
#   MODEL  FOLD DATASET COLOR_SPACE  WEIGHTED_LOSS  TRUE_NEGATIVES  \
# 5   vgg     1     ROS         RGB           True            1697
# 8   vgg     4     ROS         RGB           True            1673
# 6   vgg     2     ROS         RGB           True            1685
# 3   vgg     4     ROS         RGB          False            1683
# 0   vgg     1     ROS         RGB          False            1704
# 9   vgg     5     ROS         RGB           True            1675
# 4   vgg     5     ROS         RGB          False            1680
# 7   vgg     3     ROS         RGB           True            1695
# 2   vgg     3     ROS         RGB          False            1692
# 1   vgg     2     ROS         RGB          False            1699
#
#    FALSE_POSITIVES  FALSE_NEGATIVES  TRUE_POSITIVES      LOSS       ACC  \
# 5               11              192            1516  0.227445  0.940574
# 8               17              258            1432  0.709227  0.918639
# ...

# %%
results_vgg.MCC.mean()
# Out:
# 0.8145941241886623

# %%
results_vgg.MCC.std()
# Out:
# 0.04077758474626259

# %% [markdown]
# # Results for Feature Extraction

# %%
results_feature_extraction = pd.read_csv('./data/FEATURE_EXTRACTION_VAL_RESULTS_BASELINE.csv')
results_feature_extraction
# Out:
#               MODEL  FOLD DATASET COLOR_SPACE  WEIGHTED_LOSS  TRUE_NEGATIVES  \
# 0      efficientnet     1     ROS         RGB          False            1564
# 1      efficientnet     2     ROS         RGB          False            1539
# 2      efficientnet     3     ROS         RGB          False            1574
# 3      efficientnet     4     ROS         RGB          False            1510
# 4      efficientnet     5     ROS         RGB          False            1562
# 5      efficientnet     1     ROS         RGB           True            1104
# 6      efficientnet     2     ROS         RGB           True            1125
# 7      efficientnet     3     ROS         RGB           True            1060
# 8      efficientnet     4     ROS         RGB           True            1065
# 9      efficientnet     5     ROS         RGB           True            1175
# 10  efficientnet_b4     1     ROS         RGB          False            1441
# ...

# %%
results_feature_extraction[['MODEL','DATASET','FOLD', 'COLOR_SPACE','WEIGHTED_LOSS', 'MCC', 'F1','SENSITIVITY']].sort_values(by=['MCC', 'F1', 'SENSITIVITY'], ascending=False).head()
# Out:
#            MODEL DATASET  FOLD COLOR_SPACE  WEIGHTED_LOSS       MCC        F1  \
# 41      resnet50     ROS     2         RGB          False  0.845038  0.922942
# 3   efficientnet     ROS     4         RGB          False  0.837105  0.920012
# 52           vgg     ROS     3         RGB          False  0.807186  0.905324
# 0   efficientnet     ROS     1         RGB          False  0.803024  0.899911
# 20     inception     ROS     1         RGB          False  0.802945  0.898742
#
#     SENSITIVITY
# 41     0.928362
# 3      0.942604
# 52     0.925839
# 0      0.887002
# 20     0.878220

# %% [markdown]
# # Full Training Results

# %%
results_full_training = pd.read_csv('./data/FULL_TRAINING_EFFICIENTNET_B0_ALL_DATA_RESULTS_BASELINE.csv')
results_full_training
# Out:
#           MODEL  FOLD DATASET COLOR_SPACE  WEIGHTED_LOSS  TRUE_NEGATIVES  \
# 0  EfficientNet     0     ROS         RGB          False            2814
#
#    FALSE_POSITIVES  FALSE_NEGATIVES  TRUE_POSITIVES      LOSS       ACC  \
# 0                2               28              64  0.039204  0.989684
#
#    SENSITIVITY  SPECIFITY  PRECISION        F1       AUC       MCC
# 0     0.695652    0.99929   0.969697  0.810127  0.847471  0.816723
